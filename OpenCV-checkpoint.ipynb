# %%
# for read and write for the image 
import cv2
img = cv2.imread('lena.jpg',-1)
cv2.imshow('image' ,img )
k = cv2.waitKey(0) & 0xFF
# 27 is ascii for escape key
if (k == 27):
    cv2.destroyAllWindows()
elif(k == ord("s")):
    cv2.imwrite('Lena_copy.png',img)
    cv2.destroyAllWindows()

# %%
#for read and capture the video 
import cv2 
cap = cv2.VideoCapture(0);
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc,20.0,(640 ,480))

while(cap.isOpened()):
    ret,frame = cap.read()
    if(ret == True ):
        
        print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        out.write(frame)
        
        gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame',gray)
    
        if((cv2.waitKey(1) & 0xFF) == ord("q")):
            break
    else:
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
#draw the geometric shapes using opencv
import numpy as np 
import cv2

img = cv2.imread('Lena.jpg',1)
#or
#img = np.zeros([512 , 512 , 3],np.uint8) #height , width , 3
img = cv2.line(img ,(0,0),(255,255),(0,255,0) , 5 ) # img , cordiante start ,codinate end , BGR ,,THickness COLOr
#use rbg color picker for color
img = cv2.arrowedLine(img ,(0,255),(255,255),(0,255,0) , 5 )
img = cv2.rectangle(img ,(384,0),(510, 128),(0,0,255), 5 ) #img , point1top left and pount2 , color , thickness
#if we put -1 instead of thickness it will fill the color
img = cv2.circle(img ,(447 , 63), 63 , (0,255,0), 5) #img , center , radius , color, thickness
#to put the text 
font = cv2.FONT_HERSHEY_SCRIPT_SIMPLEX
img = cv2.putText(img ,'OpenCv',(10 ,500),font ,4,(0,255,255),10 ,cv2.LINE_AA ) #img , text , coordinates , font , color , thickess ,Linestylee
cv2.imshow('IMAGE',img)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#to add properties in captured video
import cv2
cap = cv2.VideoCapture(0)
print(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) #every property has a number associated with it 
print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.set(3 , 3000 )
cap.set(4 , 3000)

print(cap.get(3))
print(cap.get(4))


while(cap.isOpened()):
    ret , frame = cap.read()
    if ret == True:
        gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
        cv2.imshow('FRAME',frame)
        
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %%
#Read dates and time in open cv
import cv2
import datetime
cap = cv2.VideoCapture(0)
print(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) #every property has a number associated with it 
print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#cap.set(3 , 3000 )
#cap.set(4 , 3000)

#print(cap.get(3))
#print(cap.get(4))


while(cap.isOpened()):
    ret , frame = cap.read()
    if ret == True:
        font = cv2.FONT_HERSHEY_SIMPLEX
        text ="WIDTH :"+str(cap.get(3)) + "    HEIGHT :" + str(cap.get(4))
        datet = str(datetime.datetime.now())
        frame = cv2.putText(frame ,datet , (10 , 50) , font , 1 , (0 , 255 , 255) , 2 ,cv2.LINE_AA)
        #if you gonna write the text in the second argumnet it will print the width and height 
        # 1 frame , kya print krna hai , 3 coordinates 4 font 5 font size ,6coloe , 7 line size ,font type
        cv2.imshow('FRAME',frame)
        
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
#  # HANdle the mouse cick event

# %%
import numpy as np
import cv2
# to print the various events in the cv2 library 
##events = [i for i in dir(cv2) if 'EVENT' in i ]
##print(events)
def click_event(event , x , y , flags , param ):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x ," ", y)
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + " , " +str(y)
        cv2.putText(img ,strXY , (x , y) ,  font , 0.5 , ( 255 , 255 , 0 ) , 2)
        cv2.imshow('image' , img )
    if event == cv2.EVENT_RBUTTONDOWN:
        #print out the bgr chanel of the image
        blue = img[y , x , 0]
        green = img[y , x , 1]
        red = img[y , x , 2]
        font = cv2.FONT_HERSHEY_SIMPLEX
        strBGR = str(blue) + " , " +str(green) + "," + str(red)
        cv2.putText(img ,strBGR , (x , y) ,  font , 0.5 , ( 0 , 255 , 255 ) , 2)
        cv2.imshow('image' , img )
#img = np.zeros((512,512,3 ),np.uint8)
img = cv2.imread('Lena.jpg')
cv2.imshow('image',img)
    
cv2.setMouseCallback('image' , click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#draw points and connecting it by line s
import numpy as np
import cv2
# to print the various events in the cv2 library 
##events = [i for i in dir(cv2) if 'EVENT' in i ]
##print(events)
def click_event(event , x , y , flags , param ):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img ,(x , y) , 3 , (0, 0 , 255) , -1 )
        #img , cordinates, radius , color , fill color
        points.append((x,y))
        if len(points) >= 2:
            cv2.line(img ,points[-1], points[-2] , (255 , 0 , 0 ) , 5)
        cv2.imshow('image' , img )
    
img = np.zeros((512,512,3 ),np.uint8)
#img = cv2.imread('Lena.jpg')
cv2.imshow('image',img)
points = []    
cv2.setMouseCallback('image' , click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#click and get the color in the second window 
import numpy as np
import cv2
# to print the various events in the cv2 library 
##events = [i for i in dir(cv2) if 'EVENT' in i ]
##print(events)
def click_event(event , x , y , flags , param ):
    if event == cv2.EVENT_LBUTTONDOWN:
        blue = img[x , y , 0]
        green= img[x , y ,1]
        red = img[x , y ,2]
        cv2.circle(img , (x,y) , 4 , (0, 0, 255) , -1)
        my_colorImage = np.zeros((512 ,512 , 3) , np.uint8)
        
        my_colorImage[:] = [blue , green , red]
        
        cv2.imshow('color',my_colorImage)
    
#img = np.zeros((512,512,3 ),np.uint8)
img = cv2.imread('Lena.jpg')
cv2.imshow('image',img)
points = []    
cv2.setMouseCallback('image' , click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cv.split , cv merge , cvresize
import numpy as np 
import cv2 

img = cv2.imread('messi5.jpg')
img2 = cv2.imread('opencv-logo.png')

print(img.shape) #retrun a tuple contains no of rows  , colomus , channels
print(img.size) #return pixel
print(img.dtype) #return datatype of the image

b,g,r = cv2.split(img) #split the image in 3 channels give the bgr channels of the image 

img = cv2.merge((b, g,r) ) #merge

# ROI reigion of interest jaha tum kaaam krna cahate ho specific jagah
ball = img[280:340  , 330 : 390]#coordinates
img[273:333 , 100 : 160] = ball
img = cv2.resize(img , (512 ,512))
img2 = cv2.resize(img2 , (512 ,512))
#dst = cv2.add(img , img2); #sizes should be same 
dst = cv2.addWeighted(img,0.9 , img2 , 0.1  , 0);
cv2.imshow('image', dst)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # BInary for masks
# ##BITWISE OPERTIONs

# %%
import cv2
import numpy as np

img1 = np.zeros((250 , 500 , 3),np.uint8)
img1 = cv2.rectangle(img1 ,(200 , 0) , (300 ,100) , ( 255 , 255 ,255) , -1)
img2= cv2.imread('image_1.png')

bitAnd = cv2.bitwise_and(img2 , img1)

cv2.imshow("BITAND",bitAnd)
cv2.imshow("img1",img1)
cv2.imshow("img2",img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Trag Bars in OPen cv

# %%
#to change the value at the runtime
import numpy as np
import cv2 as cv
def nothing(x):
    print(x)

img = np.zeros((300 , 512 , 3), np.uint8)
cv.namedWindow('Image')

cv.createTrackbar('B' ,'Image' , 0 , 255, nothing)
cv.createTrackbar('G' ,'Image' , 0 , 255, nothing)
cv.createTrackbar('R' ,'Image' , 0 , 255, nothing)

switch = ' 0 : 0FF\n : ON'
cv.createTrackbar(switch , 'Image' , 0 , 1 , nothing)
while(1):
    cv.imshow("Image",img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break 
    b = cv.getTrackbarPos('B' , "Image")
    g = cv.getTrackbarPos('G' , "Image")
    r = cv.getTrackbarPos('R' , "Image")
    s = cv.getTrackbarPos(switch , "Image")
    
    if s == 0 :
        img[:] =0
    else:
        img[:] = [b , g , r]
    
cv.destroyAllWindows()

# %%
# to print the current vlaue on the image 
import numpy as np
import cv2 as cv
def nothing(x):
    print(x)


cv.namedWindow('Image')

cv.createTrackbar('CP' ,'Image' , 10 , 400, nothing)

switch = ' color/gray'
cv.createTrackbar(switch , 'Image' , 0 , 1 , nothing)
while(1):
    img = cv.imread("lena.jpg")
    pos = cv.getTrackbarPos('CP' , "Image")
    font = cv.FONT_HERSHEY_SIMPLEX
    cv.putText(img ,str(pos) , (50 , 150) ,font , 4 , (0 , 0 , 255))
    
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break 
    s = cv.getTrackbarPos(switch , "Image")
    
    if s == 0 :
        pass
    else:
        img = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
    img = cv.imread("lena.jpg")
    
cv.destroyAllWindows()
# Out:
# 1
# 90
# 170
# 250
# 330

# %% [markdown]
# HSV(Hue ,saturation and VALue)(HEX CONE COLOR MODEL )
# when we need illuminance used where color plays and important roll
#
# 1 >>> Hue corresponds to the color compenents (base pigments ) hence just by selecting a     range of hue you can select any color (0 - 360)
#
# 2 >>> Saturation is the amouny of color(depth) of the pigment (dominance of HUE)( 0 -100%)
#
# 3 >>>   Value is basically the brightness of the color (0 -100 %)

# %%
# OBJect recognization from aimage 
import cv2 
import numpy as np

def nothing (x):
    pass

cv2.namedWindow("Tracking")
cv2.createTrackbar("LHue ","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("LSaturation","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("LValue","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("UHue","Tracking", 255, 255 , nothing)
cv2.createTrackbar("Usaturation","Tracking", 255 , 255 , nothing)
cv2.createTrackbar("UValue","Tracking", 255 , 255 , nothing)
while True :
    frame = cv2.imread("smarties.png")
    hsv = cv2.cvtColor(frame ,cv2.COLOR_BGR2HSV)
    
    l_h = cv2.getTrackbarPos("LHue","Tracking")
    l_s = cv2.getTrackbarPos("LSaturation","Tracking")
    l_v = cv2.getTrackbarPos("LValue","Tracking")
    
    u_h = cv2.getTrackbarPos("UHue","Tracking")
    u_s = cv2.getTrackbarPos("Usaturation","Tracking")
    u_v = cv2.getTrackbarPos("UValue","Tracking")
    
    l_b = np.array([l_h , l_s , l_v ])
    u_b = np.array([u_h , u_s , u_v])
    
    mask = cv2.inRange(hsv , l_b, u_b)
    
    res = cv2.bitwise_and(frame , frame , mask  = mask )
    
    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)
    
    key =cv2.waitKey(1)
    
    if key == 27:
        break 
cv2.destroyAllWindows()

# %%
# oBJECT RECOGNIZATION FROM LIVE VIEO 
import cv2 
import numpy as np

def nothing (x):
    pass

cap = cv2.VideoCapture(0);
cv2.namedWindow("Tracking")
cv2.createTrackbar("LHue ","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("LSaturation","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("LValue","Tracking", 0 , 255 , nothing)
cv2.createTrackbar("UHue","Tracking", 255, 255 , nothing)
cv2.createTrackbar("Usaturation","Tracking", 255 , 255 , nothing)
cv2.createTrackbar("UValue","Tracking", 255 , 255 , nothing)
while True :
    #frame = cv2.imread("smarties.png")
    _,frame = cap.read()
    hsv = cv2.cvtColor(frame ,cv2.COLOR_BGR2HSV)
    
    l_h = cv2.getTrackbarPos("LHue","Tracking")
    l_s = cv2.getTrackbarPos("LSaturation","Tracking")
    l_v = cv2.getTrackbarPos("LValue","Tracking")
    
    u_h = cv2.getTrackbarPos("UHue","Tracking")
    u_s = cv2.getTrackbarPos("Usaturation","Tracking")
    u_v = cv2.getTrackbarPos("UValue","Tracking")
    
    l_b = np.array([l_h , l_s , l_v ])
    u_b = np.array([u_h , u_s , u_v])
    
    mask = cv2.inRange(hsv , l_b, u_b)
    
    res = cv2.bitwise_and(frame , frame , mask  = mask )
    
    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)
    
    key =cv2.waitKey(1)
    
    if key == 27:
        break 
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # simple image thresholding

# %% [markdown]
# thresholding is the segmentaion technique used for the sepration of objects from the background
#
# it process involve the comparing each pixel in the image with the threshold value
# divides all the pixels in the input image into two groups
#
# 1st those have the intensity value less than threshold
# and other is the greater one
#
# only in grayscale

# %%
import cv2 as cv
import numpy as np
img = cv.imread('gradient.png',0)
_,th1 = cv.threshold(img , 50 , 255 ,cv.THRESH_BINARY)
_,th2 = cv.threshold(img , 200 , 255 ,cv.THRESH_BINARY_INV)
_,th3 = cv.threshold(img , 127 , 255 ,cv.THRESH_TRUNC)
_,th4 = cv.threshold(img , 127 , 255 ,cv.THRESH_TOZERO)
_,th5 = cv.threshold(img , 127 , 255 ,cv.THRESH_TOZERO_INV)
cv.imshow("th1",th1)
cv.imshow("th2",th2)
cv.imshow("th3",th3)
cv.imshow("th4",th4)
cv.imshow("th5",th5)

cv.imshow("Image", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# # Adaptive threshold

# %% [markdown]
# it is calculated  for the smaller reigion

# %%
import cv2 as cv
import numpy as np 

img = cv.imread('sudoku.png', 0 ) 
_,th1 = cv.threshold(img , 127 , 255 ,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img , 255 , cv.ADAPTIVE_THRESH_MEAN_C , cv.THRESH_BINARY ,11  ,2 )
th3 = cv.adaptiveThreshold(img , 255 , cv.ADAPTIVE_THRESH_GAUSSIAN_C , cv.THRESH_BINARY ,11  ,2 )
cv.imshow("Image", img)
cv.imshow("th1",th1)
cv.imshow("th3",th3)
cv.imshow("th2",th2)

cv.waitKey(0) 
cv.destroyAllWindows()

# %% [markdown]
# # Matplot lib

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("Lena.jpg",-1)
cv2.imshow("image",img)
img = cv2.cvtColor(img ,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.xticks([],plt.yticks([]))
plt.show()
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt 
img = cv.imread('gradient.png',0)
_,th1 = cv.threshold(img , 50 , 255 ,cv.THRESH_BINARY)
_,th2 = cv.threshold(img , 200 , 255 ,cv.THRESH_BINARY_INV)
_,th3 = cv.threshold(img , 127 , 255 ,cv.THRESH_TRUNC)
_,th4 = cv.threshold(img , 127 , 255 ,cv.THRESH_TOZERO)
_,th5 = cv.threshold(img , 127 , 255 ,cv.THRESH_TOZERO_INV)

titles = ["Original ", "Image" , "Binary","Binary_inverse" , "trunc","Tozero" ,"Tozero_inverse"] 
images=[img , th1 , th2 , th3 , th4 , th5 ]

for i in range(6):
    plt.subplot(2 , 3 , i+1) ,plt.imshow(images[i] , 'gray')#noofrows , no of col ,index
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
cv.waitKey()
cv.destroyAllWindows()

# %% [markdown]
# # morphological Transformation

# %% [markdown]
# morphological transformation are some simple operation based on the image shape
#
# normally performed on binaty images
#
# A kernal tells you how to change the value of any pixel by combining it with different amounts of the neighbouring pixels

# %%
import cv2 as cv
import numpy as np
# %matplotlib notebook

from matplotlib import pyplot as plt 

img = cv.imread("smarties.png",cv.IMREAD_GRAYSCALE)
_,mask = cv.threshold(img , 220 , 255 ,cv.THRESH_BINARY_INV)
#dilation to remove the black dots from the imkg
kernal = np.ones((5,5 ),np.uint8)
dilation = cv.dilate(mask , kernal , iterations = 2)
#erosion  errodes the boundary of the forground images
erosion = cv.erode(mask , kernal , iterations = 1)

#opening name of erosion followed by dilayion 
opening = cv.morphologyEx(mask , cv.MORPH_OPEN , kernal)

#closing dilation is followed by erosion 
closing = cv.morphologyEx(mask , cv.MORPH_CLOSE , kernal)

#morphological gradient is difference of dilation and erosion of the image
#top hat is the difference of the image and the opening of the image 
gradient  = cv.morphologyEx(mask , cv.MORPH_GRADIENT , kernal)
tophat = cv.morphologyEx(mask , cv.MORPH_TOPHAT , kernal)



titles =['image' , 'mask' , 'dilation' , "erosion " ,'opening' ,'closing' ,'gradient' , 'Top Hat ']
images=[img, mask, dilation , erosion , opening , closing , gradient ,tophat]

for i in range(8):
    plt.subplot(2 ,4  , i+1 ) , plt.imshow(images[i],'gray')
    plt.title([titles[i]])
    plt.xticks([],plt.yticks([]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7666666666667">

# %% [markdown]
# # `SMoothing or Blurring images in Open CV

# %% [markdown]
# Homogenous filter , Gaussian filter , Median , bilateral filter etc
#
#
# homogenous filter is the most simple filter , each output pixel is the mean of its kernal neighbors
#
# K = 1 /k(width)* k(height)
#
# As in one dimensional signals images also can be filtered with the various low pass -pass filters(LPF) , high pass filters(HPF) etxc
#
# LPF helps in removing noises , blurring the images
# HPF filters helps in finding edges in the images
#
# BLur method or averaging
#
# Guassian filter is nothing but using different weight kernal in both x and y direction
# pixel located in middle have higher weight and decreases as we move along the sides
#
# Median filter is something that replace each pixel's value with the median of its neighboring pixels.This method is great when dealing with salt and pepper noise
#
# white pixels dissorted in black -------salt in pepper
#
# Bilateral filter for edges to remain sharp

# %%
import cv2 as cv
import numpy as np 
from matplotlib import pyplot as plt 
# %matplotlib notebook

img =cv.imread('lena.jpg')
img =cv.cvtColor(img , cv.COLOR_BGR2RGB)

kernal = np.ones((5 ,5 ), np.float32)/25 # 25 is the multiplication of width and height 
dst = cv.filter2D(img , -1 , kernal)
blur = cv.blur(img , (5,5))
gblur =cv.GaussianBlur(img , (5,5), 0 )
median = cv.medianBlur(img , 5) # kernal sizze should be not be 1 it must be odd
bi=cv.bilateralFilter(img , 9 , 75 , 75 ) #source , diameter , sigma size and sizma filter

titles = ['image ' ,'2D convulution ' , 'blur' , 'gaussian blur' , 'Median', 'Bilateral filter ']
images = [img ,dst , blur , gblur , median , bi]




for i in range (6):
    plt.subplot(2 , 3, i +1 ),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Image Gradient in Open cv

# %% [markdown]
# A Image gradien is a directional change in the intensity or color in an image
#
# 1: Lapilacian Derivative
# 2: Sobian x
# 3: sobian Y

# %%
# %matplotlib notebook
import cv2 
import numpy as np 
from matplotlib import pyplot as plt 

img = cv2.imread("sudoku.png",cv.IMREAD_GRAYSCALE)
lap = cv2.Laplacian(img , cv2.CV_64F , ksize = 3)
lap = np.uint8(np.absolute(lap))
sobelx = cv2.Sobel(img, cv2.CV_64F , 1 , 0  )     #d x = 1 , d y = 0 the directions  ()order of derivative
sobely = cv2.Sobel(img ,cv2.CV_64F , 0 , 1)
sobelx=np.uint8(np.absolute(sobelx))
sobely=np.uint8(np.absolute(sobely))
sobelcombine = cv2.bitwise_or(sobelx , sobely)


titles = ['image' , 'Laplacian' , 'Sobelx' , "Sobel y" ,"combined"]
images = [img , lap , sobelx , sobely , sobelcombine]

for i in range(5):
    plt.subplot(2 , 3 , i + 1 ) , plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4833333333333">

# %% [markdown]
# # Canny Edge detection Method

# %% [markdown]
# The canny edge detector is an edge detection operator that uses a multistage algoritm to detect a wide range of edges in images . It was developed by JOhn F canny in 1986
#
# The canny edge detection algo is coomposed of 5 steps
#
# 1: Noise reduction
# 2: Gradient calculation
# 3: NOn Maximum suppression
# 4: Double threshold
# 5 : Edge tracking by hystersis

# %%
import cv2 as cv 
import numpy as np 
from matplotlib import pyplot as plt

img  = cv.imread("messi5.jpg" , 0)
canny = cv.Canny(img , 100 , 200 ) #souce , threshold1 , threshold 2
lap = cv2.Laplacian(img , cv2.CV_64F , ksize = 3)
lap = np.uint8(np.absolute(lap))
sobelx = cv2.Sobel(img, cv2.CV_64F , 1 , 0  )     #d x = 1 , d y = 0 the directions  ()order of derivative
sobely = cv2.Sobel(img ,cv2.CV_64F , 0 , 1)
sobelx=np.uint8(np.absolute(sobelx))
sobely=np.uint8(np.absolute(sobely))



titles = ['image' ,'canny' ,'Laplacian' ,'Sobelx' , "Sobel y" ]
images = [img , canny ,lap , sobelx , sobely]

for i in range(5):
    plt.subplot(2 , 3 , i+1) , plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7833333333333">

# %% [markdown]
# # Image pyramid in OpenC

# %% [markdown]
# for images with different resolutions and detecting the objects in the pictures
#
# Pyramid is a type of multiscale signal representation in which a signal or an image is subjected to repeated smoothing and subsampling
#
# 1 st the orginal above the half the above the half
#
#
# Two types of pyramid
#
# 1: Gaussian pyramid : the repeat filtering and repeated the subsetting
#
# Two methods are :
# PyrUP
# PYRDown
#
# 2: laplacian pyramid are formed from the gaussian pyramid
#     A level in laplacian pyramid is formed by the difference  between  that level in Gaussian Pyramid and expanded versions of its upper level in Gaussian Pyramid
#
#
#
# USes:
#
#          help in the blend and reconstructing the image

# %%
import cv2 as cv
import numpy as np 

img = cv.imread("Lena.jpg")
layer =img.copy()

gp = [img]

for i in range(6):
    layer= cv.pyrDown(layer)
    gp.append(layer)
    #cv.imshow(str(i) ,layer)
    
layer =gp [5]
cv.imshow("upperlevel gaussian pyramid" , layer)
lp = [layer]

for i in range(5 , 0 , -1):
    gaussianextended = cv.pyrUp(gp [i])
    laplacian = cv.subtract(gp[i - 1] ,gaussianextended)
    cv.imshow(str(i) , laplacian)
cv.imshow("Original Image " , img )
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# # Image blending using image pyramids

# %% [markdown]
# For image blending we need to do the 5 steps
#
# 1: load the two images of apple and orange
#
# 2: Find the Gaussian pyramid for the apple and orange (in this examplenumber of level is 6)
#
# 3: From gaussian Pyramids , FInd the Laplacian Pyramids
#
# 4: Now join the left half of the apple and right half of the orange in each levels  of laplacian pyramids
#
# 5: Finally from this joint image pyramids , reconstruct the original image.

# %%
import cv2 as cv
import numpy as np

apple = cv.imread("apple.jpg")
orange = cv.imread("orange.jpg")
print(apple.shape)
print(orange.shape)

apple_orange = np.hstack((apple[:, :256] , orange[: , 256 :]))

#generate the gaussian pyramid for apple
apple_copy = apple.copy()
gp_apple = [apple_copy]

for i in range(6):
    apple_copy = cv.pyrDown(apple_copy)
    gp_apple.append(apple_copy)
    
#generate the gaussian pyramid for orange
orange_copy = orange.copy()
gp_orange = [orange_copy]

for i in range(6):
    orange_copy = cv.pyrDown(orange_copy)
    gp_orange.append(orange_copy)
#generate the laplacian for apple

apple_copy = gp_apple[5]
lp_apple = [apple_copy ]
for i in range(5, 0 , -1 ):
    
    gaussian_extended = cv.pyrUp(gp_apple[i])
    laplacian = cv.subtract(gp_apple[i -1 ] , gaussian_extended)
    lp_apple.append(laplacian)
    
#generate the laplacian for orange

orange_copy = gp_orange[5]
lp_orange = [orange_copy ]
for i in range(5, 0 , -1 ):
    
    gaussian_extended = cv.pyrUp(gp_orange[i])
    laplacian = cv.subtract(gp_orange[i -1 ] , gaussian_extended)
    lp_orange.append(laplacian)
#Now add left and right halves of inmages in each level 

apple_orange_pyramid = []
n = 0
for apple_lap , orange_lap  in zip(lp_apple , lp_orange):
    n +=1
    cols , rows , ch = apple_lap.shape
    laplacian = np.hstack((apple_lap[: , 0 : int(cols/2)] , orange_lap [: , int(cols/2) :]))
    apple_orange_pyramid.append(laplacian)
#reconstruct an image
apple_orange_reconstruct = apple_orange_pyramid[0]
for i in range(1 , 6):
    apple_orange_reconstruct = cv.pyrUp(apple_orange_reconstruct)
    apple_orange_reconstruct = cv.add(apple_orange_pyramid[i] , apple_orange_reconstruct)
cv.imshow('apple',apple)
cv.imshow('orange',orange)
cv.imshow("orange_apple",apple_orange)
cv.imshow("orange_apple_recontructed",apple_orange_reconstruct)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# (512, 512, 3)
# (512, 512, 3)

# %% [markdown]
# # Controus

# %% [markdown]
# Controus is the curve joing all the continous points along the boundary whihc as same color or the boundary
#
# controus is a python list of all the contours in the image.EAch indiviual contour is a NUmpy array of (X,Y) coordinates of boundary points of the object
#
# heirechy is option contains the information about the topo logy

# %%
import numpy as np
import cv2 as cv

img = cv.imread("logo.png")
imgray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

ret , thresh = cv.threshold(imgray , 127 , 255 , 0 )
contours  , hierachy = cv.findContours(thresh , cv.RETR_TREE , cv.CHAIN_APPROX_NONE)

print("number of contours ="+ str(len(contours)))
print(contours[0])

cv.drawContours(img , contours , -1 , (0 , 255 , 0) , 3) # sosurce , controus , controus index -1 will print all the controus in the image  , color , thickness

cv.imshow('Image' , img)
cv.imshow("image_GRAY " ,imgray )

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# number of contours =9
# [[[158 637]]
#
#  [[157 638]]
#
#  [[156 638]]
#
#  [[155 638]]
#
#  [[154 638]]
#
#  [[153 638]]
#
#  [[152 638]]
#
#  [[151 639]]
#
#  [[150 639]]
#
#  [[149 640]]
#
#  [[148 640]]
#
#  [[147 641]]
#
#  [[147 642]]
#
#  [[146 643]]
#
#  [[146 644]]
#
#  [[145 645]]
#
#  [[145 646]]
#
#  [[145 647]]
#
#  [[145 648]]
#
#  [[144 649]]
#
#  [[144 650]]
#
#  [[144 651]]
#
#  [[144 652]]
#
#  [[144 653]]
#
#  [[144 654]]
#
#  [[144 655]]
#
#  [[144 656]]
#
#  [[144 657]]
#
#  [[143 658]]
#
#  [[143 659]]
#
#  [[143 660]]
#
#  [[143 661]]
#
#  [[143 662]]
#
#  [[143 663]]
#
#  [[143 664]]
#
#  [[143 665]]
#
#  [[143 666]]
#
#  [[143 667]]
#
#  [[143 668]]
#
#  [[144 669]]
#
#  [[144 670]]
#
#  [[144 671]]
#
#  [[144 672]]
#
#  [[144 673]]
#
#  [[144 674]]
#
#  [[144 675]]
#
#  [[144 676]]
#
#  [[144 677]]
#
#  [[145 678]]
#
#  [[145 679]]
#
#  [[145 680]]
#
#  [[145 681]]
#
#  [[146 682]]
#
#  [[146 683]]
#
#  [[147 684]]
#
#  [[148 685]]
#
#  [[149 686]]
#
# ...

# %% [markdown]
# # MOtion detecting

# %%
import cv2 as cv
import numpy as np

cap = cv.VideoCapture('vtest.avi')
ret , frame1 = cap.read()
ret , frame2 = cap.read()




while( cap.isOpened()):
    diff =cv.absdiff(frame1 ,frame2)
    gray = cv.cvtColor(diff , cv.COLOR_BGR2GRAY)
    blur = cv.GaussianBlur(gray ,(5,5) , 0 )
    _,thresh = cv.threshold(blur , 20 , 255 , cv.THRESH_BINARY)
    dilated =  cv.dilate(thresh  , None , iterations = 3)
    contours , _ =cv.findContours(dilated , cv.RETR_TREE , cv.CHAIN_APPROX_SIMPLE)
    
    for contour in contours:
        (x , y  , width , height ) = cv.boundingRect(contour)
        if cv.contourArea(contour) < 900 :
            continue
        cv.rectangle(frame1 , (x , y) , (x + width  , y +height ) ,( 0 , 255 , 0)  , 2)
        cv.putText(frame1 , "Status : {}". format('Movement ') , ( 10 , 20 ) , cv.FONT_HERSHEY_SCRIPT_SIMPLEX, 1  , 
                                                  (0 , 0 , 255) , 3)
    #cv.drawContours(frame1 , contours , -1  , (0 , 255 , 0) , 2)
    cv.imshow("feed", frame1 )
    
    frame1 = frame2
    ret , frame2 = cap.read()
    
    
    
    if cv.waitKey(40) == 27:
        break
cv.destroyAllWindows()
cap.release()

# %% [markdown]
# # DEtecting simple objects

# %%
import cv2 as cv
import numpy as np

img = cv.imread('a.jpg')
imgGrey = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
_,thresh =cv.threshold(imgGrey , 240 , 255 , cv.THRESH_BINARY )
contours , _ = cv.findContours(thresh   , cv.RETR_TREE , cv.CHAIN_APPROX_NONE)


for contour in contours :
    approx = cv.approxPolyDP(contour , 0.01 * cv.arcLength(contour , True) , True)
    #episloion arc length finds the path length , if its closed or open contour
    cv.drawContours(img , [approx] , 0 ,  (0,0,0) , 5 )
    x = approx.ravel()[0] 
    y = approx.ravel()[1] - 5
    if (len(approx) == 3):
        cv.putText(img , "Triangle" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 255 )  )
    
    elif  (len(approx) == 4):
        x , y , w , h = cv.boundingRect(approx)
        aspectRatio = float(w) / h 
        print(aspectRatio)
        if aspectRatio >= 0.95 and aspectRatio <= 1.05:
            cv.putText(img , "Square" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
        else:
            cv.putText(img , "Rectangle" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
                
        
    elif  (len(approx) == 5):
        cv.putText(img , "Pentagon" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
    elif (len(approx) == 6):
        cv.putText(img , "Hexagon" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
    elif (len(approx) == 10):
        cv.putText(img , "Star" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
    else:
        cv.putText(img , "Circle" , (x , y) , cv.FONT_HERSHEY_COMPLEX , 0.5 , (0 , 0 , 0 )  )
    
cv.imshow('shapes' , img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 1.0436363636363637
# 1.0093457943925233
# 1.0
# 1.8314606741573034

# %% [markdown]
# # <HIstograms in Opencv ( hist gievs the intensity , contrast etc distribution of the given img )

# %%
import numpy as np
import cv2 as cv
# %matplotlib notebook

from matplotlib import pyplot as plt 
img = cv.imread("Lena.jpg" , 0 )

#img = np.zeros((200  ,200 ) , np.uint8)
#cv.rectangle(img , (0,100) , (200 ,200) ,(255) , -1 )
#cv.rectangle(img , (0,50) , (100 ,100) ,(127) , -1 )
#b, g, r =cv.split(img)
hist = cv.calcHist([img] , [0] ,None , [256] , [0 , 256]  )
plt.plot(hist)
#cv.imshow("img" , img)
#cv.imshow("b" , b)
#cv.imshow("g" , g)
#cv.imshow("r" , r)
#plt.hist(img.ravel() , 256 , [0,256])# y axis no of pixels 20 x20
#plt.hist(b.ravel() , 256 , [0,256]) 
#plt.hist(g.ravel() , 256 , [0,256]) 
#plt.hist(r.ravel() , 256 , [0,256]) 
#plt.show()


cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %% [markdown]
# # Template Matching in OpenCV

# %% [markdown]
# Template matching is the method of searching and a template image in the large imagee

# %%
import cv2 as cv 
import numpy as np 

img = cv.imread("messi5.jpg")
grey_img = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
template = cv.imread("messi_face.jpg" , 0 )

w ,h = template.shape[ ::- 1]
res = cv.matchTemplate(grey_img  , template , cv.TM_CCOEFF_NORMED)
print(res)
threshold = 0.9
loc = np.where(res  >= threshold)
print(loc)
for pt in zip(*loc[::-1]):
    cv.rectangle(img , pt  , (pt [0] + w , pt[1] +h ) , (0 , 0, 255) ,  2)
cv.imshow("img" , img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# [[-0.24663569 -0.23268595 -0.21160227 ... -0.03647362 -0.03088495
#   -0.02199894]
#  [-0.22071482 -0.20804198 -0.1887487  ... -0.04720383 -0.0456275
#   -0.04027159]
#  [-0.19542661 -0.18433249 -0.16611086 ... -0.05731553 -0.05999554
#   -0.05907805]
#  ...
#  [ 0.27279875  0.27073586  0.26887017 ...  0.02314075  0.01292261
#    0.01420202]
#  [ 0.2884807   0.29745808  0.3006717  ... -0.03937317 -0.04560177
#   -0.05528652]
#  [ 0.3167521   0.30737633  0.31033137 ... -0.07842685 -0.0755497
#   -0.07771508]]
# (array([85], dtype=int32), array([220], dtype=int32))

# %% [markdown]
# # Hough line (half transform method )

# %% [markdown]
# hough transform is a popular technique to detect any shapeif you can represent that shape in a mathematical form . it can detect the shape even if it is broken or distortes a little bit . if you want a geomertical oder of image you can use hough transformation
# for example to find the slope or intercept .
#
# A line in the image can be represented by two cvariables . For example
#
# 1 : in cartesian cordinate system  y = mx + c
# 2 : in polar coordinates xcos0 + y sin0 = r
#
# we will use the polar coordinates
#
#
# hough transform algoritm
#  1: Edge detection eg: using the Canny edge detector
#  2: Mapping of edge points to the hough space and the storage in an accumulator
#  3: interpreatation of the accumulator to yield lines of infinte length. the interperetation is done by thresholding and possibly other constraint s
#
#  4: conversion of infinite lines to finite lines
#
#
#  Open cv implements two kinds of Hough line transforms
#
#  1: Standard Hough Transform (hough lines method )
#  2: The probabilistic Hogh line Transform ( HOugh lines P method)
#
#
#
#  //////////Hough lines method takes few argument //////
#  img = sorce of the image
#
#  lines = output vectors of lines. Each line is represented by a 2 or 3 elements vector (p ,0) or(p.0,votes) p is the distance from the coordinate origin (0 ,0) (top - left corner of the image ) 0 is the line roitation angle in radians.votes is the values of accumulator .
#
#  rho  = distance resulation of the accumulator in pixels
#
#  thetha = angle resolution of the accumulator in radians
#
#  threshold = accumulator threshold parameter . only those lines are returned that get enough votes ( > threshold)
#
#  min lien length = minimum length of line line segment shorter this rejected
#
#  maxline length = maximum allowed gap between  the line segments to treat them as line line

# %%
import cv2
import numpy as np

img = cv2.imread('sudoku.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 50, 150, apertureSize=3)
cv2.imshow('edges', edges)
lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)

for line in lines:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a * rho
    y0 = b * rho
    # x1 stores the rounded off value of (r * cos(theta) - 1000 * sin(theta))
    x1 = int(x0 + 1000 * (-b))
    # y1 stores the rounded off value of (r * sin(theta)+ 1000 * cos(theta))
    y1 = int(y0 + 1000 * (a))
    # x2 stores the rounded off value of (r * cos(theta)+ 1000 * sin(theta))
    x2 = int(x0 - 1000 * (-b))
    # y2 stores the rounded off value of (r * sin(theta)- 1000 * cos(theta))
    y2 = int(y0 - 1000 * (a))
    cv2.line(img, (x1, y1), (x2, y2), (0, 0, 255), 2)


cv2.imshow('image', img)
k = cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Probablistic( Hough lines P method )( eleminates the infinte length of the line )

# %%
import cv2
import numpy as np 

img = cv2.imread("road.png")
gray =cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray , 50 , 150 , apertureSize = 3)
cv2.imshow("edge " , edges)
lines = cv2.HoughLinesP(edges , 1 , np.pi / 180  , 100 , minLineLength = 100 , maxLineGap = 10 )
for line in lines :
    x1 , y1 , x2 , y2 = line[0]
    cv2.line(img , (x1,y1) , (x2 , y2) , (0 , 255 ,0 ) , 2)
cv2.imshow("image" , img)
k =cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Lane detection project

# %%
import matplotlib.pylab as plt
import cv2
import numpy as np 
# %matplotlib notebook
def region_of_interest(img , vertices ):
    mask = np.zeros_like(img)
   # channel_count = img.shape[2]
    match_mask_color = 255
    cv2.fillPoly(mask , vertices , match_mask_color)
    mask_img = cv2.bitwise_and(img , mask )
    return mask_img
def draw_the_lines(img , lines ):
    img = np.copy(img)
    blank_img = np.zeros((img.shape[0] , img.shape[1] , 3) , dtype =np.uint8)
    
    for line in lines :
        for x1 , y1 , x2 , y2 in line :
            cv2.line(blank_img , (x1 , y1 ) , ( x2 , y2 ) , (0 , 255 , 0 ) , thickness = 4 )
    img = cv2.addWeighted(img , 0.8 , blank_img , 1 , 0.0)
    return img 

    
    
                       
img = cv2.imread("road.png" )
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

print(img.shape)
height = img.shape[0]
width = img.shape[1]

region_of_interest_vertices =[ 
            (0 ,height),
            (width / 2, height /2),
            (width , height)
] 

gray = cv2.cvtColor(img , cv2.COLOR_RGB2GRAY)
canny_image = cv2.Canny(gray , 100 , 200 , )
cropped_img = region_of_interest(canny_image , np.array([region_of_interest_vertices ] , np.int32))

lines = cv2.HoughLinesP(cropped_img , rho = 6  , theta = np.pi / 60 , threshold = 160  , lines = np.array([]) , minLineLength =40 , maxLineGap = 25)

image_with_lines = draw_the_lines(img , lines)  
plt.imshow(image_with_lines)
plt.show()
# Out:
# (704, 1279, 3)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Detecting the lane lines in the video frames

# %%
#find the appropriate video and it will work
import matplotlib.pylab as plt
import cv2
import numpy as np

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    #channel_count = img.shape[2]
    match_mask_color = 255
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def drow_the_lines(img, lines):
    img = np.copy(img)
    blank_image = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)

    for line in lines:
        for x1, y1, x2, y2 in line:
            cv2.line(blank_image, (x1,y1), (x2,y2), (0, 255, 0), thickness=10)

    img = cv2.addWeighted(img, 0.8, blank_image, 1, 0.0)
    return img

# = cv2.imread('road.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
def process(image):
    print(image.shape)
    height = image.shape[0]
    width = image.shape[1]
    region_of_interest_vertices = [
        (0, height),
        (width/2, height/2),
        (width, height)
    ]
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    canny_image = cv2.Canny(gray_image, 100, 120)
    cropped_image = region_of_interest(canny_image,
                    np.array([region_of_interest_vertices], np.int32),)
    lines = cv2.HoughLinesP(cropped_image,
                            rho=2,
                            theta=np.pi/180,
                            threshold=50,
                            lines=np.array([]),
                            minLineLength=40,
                            maxLineGap=100)
    image_with_lines = drow_the_lines(image, lines)
    return image_with_lines

cap = cv2.VideoCapture('road.mp4')

while cap.isOpened():
    ret, frame = cap.read()
    frame = process(frame)
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Circle detection ( hough line transformation ) To dtect only circle in the image

# %% [markdown]
# (x -x(center))^2 + (y - y(center ))^2 = r^2
#
# x center , ycenter is the center of the circle and r is the radius of circle
#
# Hough circle takes some arguments
#
# 1: image -- 8bit single channel -- grayscale input image
#
# 2:output vector of found circles
#
# 3: method : detection method
#
# 4: dp : iverse ratio of the accumulator resoulution to the image ressolution .
#
# 5: minDist : minimum distance between the center s of the detected circles
#
# 6: param1 : first method specific parameter
#
# 7: minRadius Minimum circle radius
#
# 8: maax radius : maximum circle radius

# %%
import numpy as np
import cv2 as cv
img = cv.imread('a.jpg') # you can use the smarties.jpg image too
output = img.copy()
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
gray = cv.medianBlur(gray, 5)
circles = cv.HoughCircles(gray, cv.HOUGH_GRADIENT, 1, 20,
                          param1=50, param2=30, minRadius=0, maxRadius=0)
detected_circles = np.uint16(np.around(circles))
for (x, y ,r) in detected_circles[0, :]:
    cv.circle(output, (x, y), r, (0, 0, 0), 3)
    cv.circle(output, (x, y), 2, (0, 255, 255), 3)


cv.imshow('output',output)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# # Face detection

# %% [markdown]
# First a classifier ( namely a casacade of boosted classifiers working with haar - like features ) is trained with few hundred sample views , of a particular objects (ie  ,,. a face or a car ) called positive examples that are scaled to the same size (say  x) and negative examples - arbitary images of the same size if after the program is trained with willl select the reigion of interest
#
#
#
# Objects = cv.CascadeClassifier.detectionMULTIScale( img , scale factor , minneighbours)
#
# image = matrix of the CV_8u containing an image where objects are detected .
#
# objects = Vector of rectangle where each rectangle contains the detected object , the rectangles may be partially outside the original image
#
# scale_factors = parameterspecifying how much the image size is reduced at each image scale
#
#
# min neihbours = parametr specifying how many neighbours each candidates rectangle should have to reatin it

# %%
import cv2 as cv

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

#img = cv.imread("my.jpg")

cap = cv.VideoCapture(0)

while(cap .isOpened()):
    _ , img  = cap.read()
    gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray , 1.1 , 9)

    for ( x , y , w  , h ) in faces:
        cv.rectangle(img , (x , y ) , (x + w , y+ h ) , (0 , 255 , 0) , 3)

    cv.imshow("img" , img )
    if (cv.waitKey(1) & 0xFF == ord('q') ):
        break  


cap.release()

# %% [markdown]
# # Eye detection

# %%
import cv2 as cv

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye_tree_eyeglasses.xml')
#img = cv.imread("my.jpg")

cap = cv.VideoCapture(0)

while(cap .isOpened()):
    _ , img  = cap.read()
    gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray , 1.1 , 9)

    for ( x , y , w  , h ) in faces:
        cv.rectangle(img , (x , y ) , (x + w , y+ h ) , (0 , 255 , 0) , 3)
        roi_gray = gray[y : y+h , x:x+w]
        roi_color= img[y : y+h , x:x+w]
        eyes =eye_cascade.detectMultiScale(roi_gray)
        for (ex , ey , ew , eh ) in eyes :
            cv.rectangle(roi_color , (ex , ey) , (ex + ew  , ey + eh) , (0 , 0 , 255) , 5)

    cv.imshow("img" , img )
    if (cv.waitKey(1) & 0xFF == ord('q') ):
        break  


cap.release()

# %% [markdown]
# # Corner detection

# %% [markdown]
# # Harris Corner Detector
#
#
# 1 : determine which windows produce very large variations in intensity when moved in both X and Y directions
#
# 2 : WIth each of window found , a score R is computed
#
# 3 : After applying a thresholld to this score important corners are selected and marked
#
#
# # for determining the window
#
# E( u , v) = E w(x,y) [ I ( x + u , y + u ) - I( x , y)] ^2
#
#
# # for score
# R = det(M) - k(trace(M))^2
#
# det( M) = lamda1 * lamda2
# trace( M ) = lambda1 + lambda 2
#
# where lamda1 and lamda2 are the eigen vectors of M
#
# # Based on the value of R
#
# 1 :[R] is small which happens when labda1 and lambda2 are small the reigion is flat
#
# 2 : R < 0 wheich happpens whens lamda1 >> lambda2 or vice versa , the region is edge
#
# 3: R is large which happens when lambda1 and lambda2 are large and lambda1 - lambda2 the reigion is a corner
#
#
#
#
# # input for harris edge
#
# img = source
#
#
# block size = it is the size of neighbourhood considered for the corner detection
#
#
# k size = Aperature parameter of the Sobel derivative used
#
#
# k = Harris dectector free parameter in the equation

# %%
import cv2 as cv

import numpy as np

img = cv.imread("chessboard.png")

cv.imshow("img" , img)

gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

gray= np.float32(gray)
dat = cv.cornerHarris(gray , 2, 3 , 0.04 )

dat = cv.dilate(dat , None)

img[dat > 0.01  *dat.max()] = [ 0, 0 , 255]
cv.imshow("dat " , img )

if cv.waitKey(0) & 0xFF == 27 :
    cv.destroyAllWindows()

# %% [markdown]
# #  SHI Tomasi corner detection method

# %% [markdown]
# corners= cv.goodFeaturesToTrack(gray , 25[limit]  , 0.01[quality level ] , 10 =[min distance ] )

# %%
import numpy as np
import cv2 as cv

img = cv.imread("pic1.png")
gray = cv.cvtColor(img , cv.COLOR_BGR2GRAY)

corners= cv.goodFeaturesToTrack(gray , 600 ,0.01 , 10 )

corners = np.int0(corners)

for i in corners:
    x , y = i.ravel()
    cv.circle(img , (x , y ) , 3 , 255 , -1)
cv.imshow("img", img )
if cv.waitKey(0) & 0xff == 27 :
    cv.destroyAllWindows()

# %% [markdown]
# #  Background Substraction technique

# %% [markdown]
# fgbg = foreground background

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture('vtest.avi')
#kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3,3))
fgbg = cv.bgsegm.createBackgroundSubtractorMOG()
#fgbg = cv.bgsegm.BackgroundSubtractorGMG()
#fgbg = cv.createBackgroundSubtractorMOG2(detectShadows=True)
#fgbg = cv.createBackgroundSubtractorKNN(detectShadows=True)
while True:
    ret, frame = cap.read()
    if frame is None:
        break
    fgmask = fgbg.apply(frame)
    #fgmask = cv.morphologyEx(fgmask, cv.MORPH_OPEN, kernel)

    cv.imshow('Frame', frame)
    cv.imshow('FG MASK Frame', fgmask)

    keyboard = cv.waitKey(30)
    if keyboard == 'q' or keyboard == 27:
        break
cap.release()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-6c5465a3ddf1> in <module>
#       3 cap = cv.VideoCapture('vtest.avi')
#       4 #kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3,3))
# ----> 5 fgbg = cv.bgsegm.createBackgroundSubtractorMOG()
#       6 #fgbg = cv.bgsegm.BackgroundSubtractorGMG()
#       7 #fgbg = cv.createBackgroundSubtractorMOG2(detectShadows=True)
#
# AttributeError: module 'cv2.cv2' has no attribute 'bgsegm'

# %% [markdown]
# #  Object tracking method ( Mean Shift )

# %% [markdown]
# # another method

# %%
import cv2 as cv 

cap = cv.VideoCapture(0)

tracker = cv.TrackerMOSSE_create()
success , img = cap.read()
bbox = cv.selectROI("tracking ",img , False)
tracker.init(img , bbox) 
while(True):
    timer = cv.getTickCount()
    
    success , img = cap.read()
    fps = cv.getTickFrequency() / (cv.getTickCount() -timer)
    cv.putText(img , str(int(fps)), (75 , 50) , cv.FONT_HERSHEY_SIMPLEX , 0.7 , ( 0, 0 , 255 ) , 2)
    
    cv.imshow("Tracing",img)
    
    
    if(cv.waitKey(1) & 0xff == ord('q')):
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-59cc7df84448> in <module>
#       3 cap = cv.VideoCapture(0)
#       4
# ----> 5 tracker = cv.TrackerMOSSE_create()
#       6 success , img = cap.read()
#       7 bbox = cv.selectROI("tracking ",img , False)
#
# AttributeError: module 'cv2.cv2' has no attribute 'TrackerMOSSE_create'
